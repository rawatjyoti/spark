# %% [markdown]
# # JYOTI RAWAT

# %% [markdown]
# # To Explore Decision Tree Algorithm

# %% [markdown]
# # Loading the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np 
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
iris=pd.read_csv("iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Head

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Shape

# %%
iris.shape
# Out:
# (150, 6)

# %% [markdown]
# # Columns

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# # Index

# %%
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %% [markdown]
# # Data Modelling

# %%
y = iris['Species']
X = iris.drop('Species', axis=1)

# %%
dt = DecisionTreeClassifier()
model = dt.fit(X,y)

# %% [markdown]
# # Visualizing Decision Trees

# %% [markdown]
# We can visualize Decision Trees using only a single Python library tree of sklearn.

# %%
text = tree.export_text(dt)

# %%
print(text)
# Out:
# |--- feature_4 <= 0.80
# |   |--- class: Iris-setosa
# |--- feature_4 >  0.80
# |   |--- feature_0 <= 100.50
# |   |   |--- class: Iris-versicolor
# |   |--- feature_0 >  100.50
# |   |   |--- class: Iris-virginica

# %%
with open('decision_tree.log', 'w')as log:
    log.write(text)

# %%
fig = plt.figure(figsize=(20,10))
tree.plot_tree(dt, feature_names=iris.columns, class_names=iris['Species'] ,filled=True)
# Out:
# [Text(446.4, 453.0, 'PetalWidthCm <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]\nclass = Iris-setosa'),
#  Text(223.2, 271.8, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = Iris-setosa'),
#  Text(669.5999999999999, 271.8, 'Id <= 100.5\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]\nclass = Iris-setosa'),
#  Text(446.4, 90.59999999999997, 'gini = 0.0\nsamples = 50\nvalue = [0, 50, 0]\nclass = Iris-setosa'),
#  Text(892.8, 90.59999999999997, 'gini = 0.0\nsamples = 50\nvalue = [0, 0, 50]\nclass = Iris-setosa')]
